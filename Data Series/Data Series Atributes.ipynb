# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
import random as rnd

# %%
cities = ['London','Berlin','Warsaw','Paris']
citiesSeries = pd.Series(cities)
citiesSeries
# Out:
# 0    London
# 1    Berlin
# 2    Warsaw
# 3     Paris
# dtype: object

# %%
citiesSeries.size
# Out:
# 4

# %%
citiesSeries.nbytes
# Out:
# 32

# %%
citiesSeries.is_unique
# Out:
# True

# %%
citiesSeries.is_monotonic
# Out:
# False

# %%
citiesSeries.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
citiesSeries.values
# Out:
# array(['London', 'Berlin', 'Warsaw', 'Paris'], dtype=object)

# %%
citiesSeries.dtype
# O as object
# Out:
# dtype('O')

# %%
citiesSeries.shape
# Out:
# (4,)

# %%
monotonicList = [1,2,4,66,88]
monotonicSeries = pd.Series(monotonicList)
monotonicSeries
# Out:
# 0     1
# 1     2
# 2     4
# 3    66
# 4    88
# dtype: int64

# %%
monotonicSeries.is_monotonic
# Out:
# True

# %%
monotonicSeries.is_monotonic_increasing
# Out:
# True

# %%
monotonicSeries.is_monotonic_decreasing
# Out:
# False

# %%
dataAsFloats = [i*rnd.random() for i in range(100000)]
dataAsFloats
# Out:
# [0.0,
#  0.15431023479796424,
#  1.4291778524059926,
#  1.3951770989431087,
#  3.5890438843345587,
#  4.5399467815039865,
#  3.8342343542937285,
#  1.3183095963129725,
#  0.05611557604077788,
#  6.51598662204915,
#  0.9498999920405016,
#  1.4663390631313384,
#  6.559754231174477,
#  11.566727762366456,
#  11.113465099662035,
#  6.06452069428928,
#  11.336375450654403,
#  5.049141641122941,
#  9.040604652818502,
#  0.6943958293871346,
#  18.550883421213044,
#  17.998503865201112,
#  18.574066890885398,
#  1.1134831619741294,
#  9.110872048495294,
#  8.603473487323956,
#  13.382351082434592,
#  9.146963670663323,
#  27.743271425733905,
#  16.92168758132032,
#  1.559729626658789,
#  20.322849148883932,
#  19.47071078638958,
#  19.53709995240642,
#  19.758363806987628,
#  4.021786748337817,
#  18.429517553530815,
#  29.601023331717528,
#  32.26535033242258,
#  20.376970242194915,
#  19.523040074434846,
#  29.88796479639136,
#  21.816825620526792,
#  36.715508107755234,
# ...

# %%
dataAsFloatSeries = pd.Series(dataAsFloats)
dataAsFloatSeries.size
# Out:
# 100000

# %%
dataAsFloatSeries.nbytes
# Out:
# 800000

# %%
dataAsFloatSeries.shape
# Out:
# (100000,)

# %%
dataAsFloatSeries.axes
# Out:
# [RangeIndex(start=0, stop=100000, step=1)]

# %%
dataAsFloatSeries.dtype
# Out:
# dtype('float64')

# %%
dataAsFloatSeries.index
# Out:
# RangeIndex(start=0, stop=100000, step=1)

# %%
dataAsFloatSeries.is_unique
# Out:
# True

# %%
dataAsFloatSeries.is_monotonic
# Out:
# False

# %%
dataAsStrings = [str(i*rnd.random()) for i in range(100000)]
dataAsStrings
# Out:
# ['0.0',
#  '0.9136050721069732',
#  '0.912688246946779',
#  '2.672810843907259',
#  '2.169651578766583',
#  '1.2401652135389214',
#  '3.6548419818253266',
#  '6.0958080530148715',
#  '0.6353108864908643',
#  '7.930078110164848',
#  '2.968228419422686',
#  '1.5807082444188996',
#  '10.452970373704005',
#  '5.12581183134018',
#  '13.516616022225202',
#  '11.923548831556817',
#  '7.338869344120319',
#  '7.381175961935863',
#  '15.511733153547164',
#  '6.420993671678235',
#  '6.3158102873078175',
#  '2.46749171566855',
#  '6.909934291562134',
#  '21.64763334662211',
#  '19.276174216775786',
#  '0.9212817494550551',
#  '2.1214660186348766',
#  '12.222367345138757',
#  '1.6953676859004099',
#  '19.698686148786976',
#  '18.93539616872559',
#  '17.41236456450819',
#  '15.440598307096568',
#  '8.115910257368403',
#  '10.465426467791511',
#  '26.748805162708024',
#  '34.34091913191087',
#  '14.024941559844205',
#  '5.450271736880651',
#  '18.365392486456805',
#  '29.268214251412484',
# ...

# %%
dataAsStringsSeries = pd.Series(dataAsStrings)
dataAsStringsSeries
# Out:
# 0                       0.0
# 1        0.9136050721069732
# 2         0.912688246946779
# 3         2.672810843907259
# 4         2.169651578766583
#                 ...
# 99995     40001.18433224981
# 99996    61821.354997956354
# 99997    32932.073834155155
# 99998    63889.577031066096
# 99999    23074.992506330153
# Length: 100000, dtype: object

# %%
dataAsStringsSeries.size
# Out:
# 100000

# %%
dataAsStringsSeries.nbytes
# Out:
# 800000

# %%
dataAsStringsSeries.dtype
# Out:
# dtype('O')

# %%
dataAsStringsSeries.memory_usage(deep=True)
# Out:
# 7434860

# %%
dataAsFloatSeries.memory_usage(deep=True)
# Out:
# 800128
