# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # joins

# %%
products = pd.read_csv(r'C:\Users\maxym\Desktop\cheatsheets\pandas_anaconda_numpy\course-files\northwind-mongo-master\products.csv')
products.loc[products['ProductName']=='Ravioli Angelo']
# Out:
#     ProductID     ProductName  SupplierID  CategoryID   QuantityPerUnit  \
# 56         57  Ravioli Angelo          26           5  24 - 250 g pkgs.
#
#     UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  Discontinued
# 56       19.5            36             0            20             0

# %%
categories = pd.read_csv(r'C:\Users\maxym\Desktop\cheatsheets\pandas_anaconda_numpy\course-files\northwind-mongo-master\categories1.csv')
categories.head()
# Out:
#    CategoryID    CategoryName              Description
# 0           1       Beverages              Soft drinks
# 1           2      Condiments  Sweet and savory sauces
# 2           3     Confections                 Desserts
# 3           4  Dairy Products                  Cheeses
# 4           5  Grains/Cereals                   Breads

# %%
categories.loc[categories['CategoryID'] == 5]
# Out:
#    CategoryID    CategoryName Description
# 4           5  Grains/Cereals      Breads

# %%
suppliers = pd.read_csv(r'C:\Users\maxym\Desktop\cheatsheets\pandas_anaconda_numpy\course-files\northwind-mongo-master\suppliers.csv')
suppliers.head()
# Out:
#    SupplierID                         CompanyName                 ContactName  \
# 0           1                      Exotic Liquids            Charlotte Cooper
# 1           2          New Orleans Cajun Delights               Shelley Burke
# 2           3           Grandma Kelly's Homestead               Regina Murphy
# 3           4                       Tokyo Traders                Yoshi Nagase
# 4           5  Cooperativa de Quesos 'Las Cabras'  Antonio del Valle Saavedra
#
#            ContactTitle                    Address         City    Region  \
# 0    Purchasing Manager             49 Gilbert St.       London       NaN
# 1   Order Administrator             P.O. Box 78934  New Orleans        LA
# 2  Sales Representative             707 Oxford Rd.    Ann Arbor        MI
# 3     Marketing Manager  9-8 Sekimai Musashino-shi        Tokyo       NaN
# 4  Export Administrator          Calle del Rosal 4       Oviedo  Asturias
#
# ...

# %%
suppliers.loc[suppliers['SupplierID'] == 26]
# Out:
#     SupplierID           CompanyName       ContactName         ContactTitle  \
# 25          26  Pasta Buttini s.r.l.  Giovanni Giudici  Order Administrator
#
#                   Address     City Region PostalCode Country          Phone  \
# 25  Via dei Gelsomini 153  Salerno    NaN      84100   Italy  (089) 6547665
#
#               Fax HomePage
# 25  (089) 6547667      NaN

# %% [markdown]
# # apeend, concat

# %%
mrbean = pd.read_csv(r'C:\Users\maxym\Desktop\cheatsheets\pandas_anaconda_numpy\course-files\mrbean_facebook_statuses_join.csv',
                    usecols=['status_message_mrbean','status_type','num_likes'])
mrbean.head()
# Out:
#                                status_message_mrbean status_type  num_likes
# 0  It's time for Mr Bean and Teddy to get ready f...       video      16079
# 1                                                NaN       photo     114008
# 2                                                NaN       photo     218579
# 3  Mr Bean is ready to do some shopping but bewar...       video      20338
# 4                                                NaN       photo     215591

# %%
nasa = pd.read_csv(r'C:\Users\maxym\Desktop\cheatsheets\pandas_anaconda_numpy\course-files\nasa_facebook_statuses_join.csv',
                    usecols=['status_message_nasa','status_type','num_likes'])
nasa.head()
# Out:
#                                  status_message_nasa status_type  num_likes
# 0  This morning, the #RockOn mission with student...       photo       5142
# 1  Pluto's largest moon, Charon, is home to an un...       photo      19074
# 2  Our Restore-L mission is an endeavor to launch...       photo       7551
# 3  A new dark vortex was discovered in the atmosp...       photo      24359
# 4                                                NaN       video       2731

# %%
fb = mrbean.append(nasa,sort=True)

# %%
fb.loc[0]
# Out:
#    num_likes                              status_message_mrbean  \
# 0      16079  It's time for Mr Bean and Teddy to get ready f...
# 0       5142                                                NaN
#
#                                  status_message_nasa status_type
# 0                                                NaN       video
# 0  This morning, the #RockOn mission with student...       photo

# %%
fb = mrbean.append(nasa, sort=True, ignore_index=True)

# %%
fb.loc[0]
# Out:
# num_likes                                                            16079
# status_message_mrbean    It's time for Mr Bean and Teddy to get ready f...
# status_message_nasa                                                    NaN
# status_type                                                          video
# Name: 0, dtype: object

# %%
mrbean.rename({"status_message_mrbean" : "status_message"}, axis=1, inplace=True)

# %%
nasa.rename({"status_message_nasa" : "status_message"}, axis=1, inplace=True)

# %%
fb = mrbean.append(nasa, sort=True, ignore_index=True)

# %%
fb.head()
# Out:
#    num_likes                                     status_message status_type
# 0      16079  It's time for Mr Bean and Teddy to get ready f...       video
# 1     114008                                                NaN       photo
# 2     218579                                                NaN       photo
# 3      20338  Mr Bean is ready to do some shopping but bewar...       video
# 4     215591                                                NaN       photo

# %%
fb = pd.concat([mrbean, nasa])

# %%
fb.head()
# Out:
#                                       status_message status_type  num_likes
# 0  It's time for Mr Bean and Teddy to get ready f...       video      16079
# 1                                                NaN       photo     114008
# 2                                                NaN       photo     218579
# 3  Mr Bean is ready to do some shopping but bewar...       video      20338
# 4                                                NaN       photo     215591

# %% [markdown]
# # join

# %%
customer_names  = pd.read_csv(r'C:\Users\maxym\Desktop\cheatsheets\pandas_anaconda_numpy\course-files\northwind-mongo-master\customers.csv',
                             usecols=['CustomerID', 'CompanyName'])
customer_names.head()
# Out:
#   CustomerID                         CompanyName
# 0      ALFKI                 Alfreds Futterkiste
# 1      ANATR  Ana Trujillo Emparedados y helados
# 2      ANTON            Antonio Moreno Taquer?­a
# 3      AROUT                     Around the Horn
# 4      BERGS                 Berglunds snabbk?¶p

# %%
customer_cities = pd.read_csv(r'C:\Users\maxym\Desktop\cheatsheets\pandas_anaconda_numpy\course-files\northwind-mongo-master\customers.csv',
                             usecols=['CustomerID', 'City','Country'])
customer_cities.head()
# Out:
#   CustomerID          City  Country
# 0      ALFKI        Berlin  Germany
# 1      ANATR  M?©xico D.F.   Mexico
# 2      ANTON  M?©xico D.F.   Mexico
# 3      AROUT        London       UK
# 4      BERGS        Lule??   Sweden

# %%
len(customer_names), len(customer_cities)
# Out:
# (91, 91)

# %%
customer_cities.set_index('CustomerID', inplace=True)

# %%
customer_cities.head()
# Out:
#                     City  Country
# CustomerID
# ALFKI             Berlin  Germany
# ANATR       M?©xico D.F.   Mexico
# ANTON       M?©xico D.F.   Mexico
# AROUT             London       UK
# BERGS             Lule??   Sweden

# %%
customer_names.set_index('CustomerID', inplace=True)

# %%
customer_names.head()
# Out:
#                                    CompanyName
# CustomerID
# ALFKI                      Alfreds Futterkiste
# ANATR       Ana Trujillo Emparedados y helados
# ANTON                 Antonio Moreno Taquer?­a
# AROUT                          Around the Horn
# BERGS                      Berglunds snabbk?¶p

# %%
customer_cities.join(customer_names)
# Out:
#                     City  Country                         CompanyName
# CustomerID
# ALFKI             Berlin  Germany                 Alfreds Futterkiste
# ANATR       M?©xico D.F.   Mexico  Ana Trujillo Emparedados y helados
# ANTON       M?©xico D.F.   Mexico            Antonio Moreno Taquer?­a
# AROUT             London       UK                     Around the Horn
# BERGS             Lule??   Sweden                 Berglunds snabbk?¶p
# ...                  ...      ...                                 ...
# WARTH               Oulu  Finland                      Wartian Herkku
# WELLI            Resende   Brazil              Wellington Importadora
# WHITC            Seattle      USA                White Clover Markets
# WILMK           Helsinki  Finland                         Wilman Kala
# WOLZA           Warszawa   Poland                      Wolski  Zajazd
#
# [91 rows x 3 columns]

# %%
customer_names.reset_index(inplace=True)

# %%
customer_names.head()
# Out:
#   CustomerID                         CompanyName
# 0      ALFKI                 Alfreds Futterkiste
# 1      ANATR  Ana Trujillo Emparedados y helados
# 2      ANTON            Antonio Moreno Taquer?­a
# 3      AROUT                     Around the Horn
# 4      BERGS                 Berglunds snabbk?¶p

# %%
customer_names.join(customer_cities,on='CustomerID').head()
# Out:
#   CustomerID                         CompanyName          City  Country
# 0      ALFKI                 Alfreds Futterkiste        Berlin  Germany
# 1      ANATR  Ana Trujillo Emparedados y helados  M?©xico D.F.   Mexico
# 2      ANTON            Antonio Moreno Taquer?­a  M?©xico D.F.   Mexico
# 3      AROUT                     Around the Horn        London       UK
# 4      BERGS                 Berglunds snabbk?¶p        Lule??   Sweden

# %%
len(customer_names.join(customer_cities,on='CustomerID'))
# Out:
# 91

# %% [markdown]
# # merge
# ## better to use it because we can join by columns not only by indexes

# %%
f_2015 = pd.read_csv(r'C:\Users\maxym\Desktop\cheatsheets\pandas_anaconda_numpy\course-files\Fortune_500_2015.csv',
                    usecols=['rank','company'])
f_2015.head()
# Out:
#    rank             company
# 0     1             Walmart
# 1     2         Exxon Mobil
# 2     3             Chevron
# 3     4  Berkshire Hathaway
# 4     5               Apple

# %%
f_2016 = pd.read_csv(r'C:\Users\maxym\Desktop\cheatsheets\pandas_anaconda_numpy\course-files\Fortune_500_2016.csv',
                    usecols=['rank','company'])
f_2016.head()
# Out:
#    rank             company
# 0     1             Walmart
# 1     2         Exxon Mobil
# 2     3               Apple
# 3     4  Berkshire Hathaway
# 4     5            McKesson

# %%
companies_2015_2016 = f_2015.merge(f_2016,on='company', suffixes=['_2015','_2016'])

# %%
companies_2015_2016
# Out:
#      rank_2015                company  rank_2016
# 0            1                Walmart          1
# 1            2            Exxon Mobil          2
# 2            3                Chevron         14
# 3            4     Berkshire Hathaway          4
# 4            5                  Apple          3
# ..         ...                    ...        ...
# 461        493    Insight Enterprises        474
# 462        494  Alliance Data Systems        404
# 463        495       LifePoint Health        430
# 464        497      Wyndham Worldwide        466
# 465        498          Owens Corning        480
#
# [466 rows x 3 columns]

# %%
companies_2015_2016[companies_2015_2016['company'] == 'Microsoft']
# Out:
#     rank_2015    company  rank_2016
# 30         31  Microsoft         25

# %%
companies_2015_2016 = f_2015.merge(f_2016,on='company', how='outer', suffixes=['_2015','_2016'], indicator=True)

# %% [markdown]
# indicator = true  --> _merge

# %%
companies_2015_2016
# Out:
#      rank_2015                   company  rank_2016      _merge
# 0          1.0                   Walmart        1.0        both
# 1          2.0               Exxon Mobil        2.0        both
# 2          3.0                   Chevron       14.0        both
# 3          4.0        Berkshire Hathaway        4.0        both
# 4          5.0                     Apple        3.0        both
# ..         ...                       ...        ...         ...
# 529        NaN  Telephone & Data Systems      496.0  right_only
# 530        NaN  First American Financial      497.0  right_only
# 531        NaN                       NVR      498.0  right_only
# 532        NaN      Cincinnati Financial      499.0  right_only
# 533        NaN         Burlington Stores      500.0  right_only
#
# [534 rows x 4 columns]

# %%
only_2015 = f_2015.merge(f_2016,on='company', how='left', suffixes=['_2015','_2016'], indicator=True)

# %%
only_2016 = f_2015.merge(f_2016,on='company', how='right', suffixes=['_2015','_2016'], indicator=True)

# %%
only_2015.tail()
# Out:
#      rank_2015                    company  rank_2016     _merge
# 495        496  Pioneer Natural Resources        NaN  left_only
# 496        497          Wyndham Worldwide      466.0       both
# 497        498              Owens Corning      480.0       both
# 498        499                  Alleghany        NaN  left_only
# 499        500      McGraw Hill Financial        NaN  left_only

# %%
only_2015 = companies_2015_2016[companies_2015_2016["_merge"] == "left_only"]
only_2015.head()
# Out:
#      rank_2015                  company  rank_2016     _merge
# 83        84.0                  Safeway        NaN  left_only
# 94        95.0                  DirecTV        NaN  left_only
# 124      125.0                    Alcoa        NaN  left_only
# 164      165.0                    Kraft        NaN  left_only
# 174      175.0  TRW Automotive Holdings        NaN  left_only

# %%
only_2016 = companies_2015_2016[companies_2015_2016["_merge"] == "right_only"]
only_2016.head()
# Out:
#      rank_2015                 company  rank_2016      _merge
# 500        NaN                 Arconic      126.0  right_only
# 501        NaN             Kraft Heinz      153.0  right_only
# 502        NaN  Performance Food Group      185.0  right_only
# 503        NaN   Hertz Global Holdings      269.0  right_only
# 504        NaN         PayPal Holdings      307.0  right_only

# %%
suppliers = pd.read_csv(r'C:\Users\maxym\Desktop\cheatsheets\pandas_anaconda_numpy\course-files\northwind-mongo-master\suppliers_del_1.csv',
                       usecols=['SupplierID','CompanyName', 'City'])
suppliers.head()
# Out:
#    SupplierID                         CompanyName         City
# 0           1                      Exotic Liquids       London
# 1           2          New Orleans Cajun Delights  New Orleans
# 2           3           Grandma Kelly's Homestead    Ann Arbor
# 3           4                       Tokyo Traders        Tokyo
# 4           5  Cooperativa de Quesos 'Las Cabras'       Oviedo

# %%
products = pd.read_csv(r'C:\Users\maxym\Desktop\cheatsheets\pandas_anaconda_numpy\course-files\northwind-mongo-master\products_del_1.csv',
                      usecols=['ProductID','ProductName', 'SupplierID'])
products.head()
# Out:
#    ProductID                   ProductName  SupplierID
# 0          1                          Chai           1
# 1          2                         Chang           1
# 2          3                 Aniseed Syrup           1
# 3          4  Chef Anton's Cajun Seasoning           2
# 4          5        Chef Anton's Gumbo Mix           2

# %%
prod_and_sup = products.merge(suppliers)

# %%
f'suppliers:{len(suppliers)}, products:{len(products)}, both:{len(prod_and_sup)}'
# Out:
# 'suppliers:27, products:75, both:70'

# %%
prod_and_sup_outer = products.merge(suppliers, on='SupplierID', how='outer', indicator=True)

# %%
filtering_left = prod_and_sup_outer['_merge'] == 'left_only'

# %%
prod_and_sup_outer[filtering_left]
# Out:
#     ProductID          ProductName  SupplierID CompanyName City     _merge
# 27       22.0  Gustaf's Knäckebröd           9         NaN  NaN  left_only
# 28       23.0             Tunnbröd           9         NaN  NaN  left_only
# 48       36.0          Inlagd Sill          17         NaN  NaN  left_only
# 49       37.0           Gravad lax          17         NaN  NaN  left_only
# 50       73.0           Röd Kaviar          17         NaN  NaN  left_only

# %%
filtering_right = prod_and_sup_outer['_merge'] == 'right_only'

# %%
prod_and_sup_outer[filtering_right]
# Out:
#     ProductID ProductName  SupplierID         CompanyName      City  \
# 75        NaN         NaN          27  Escargots Nouveaux  Montceau
#
#         _merge
# 75  right_only

# %%
suppliers = pd.read_csv(r'C:\Users\maxym\Desktop\cheatsheets\pandas_anaconda_numpy\course-files\northwind-mongo-master\suppliers.csv',
                       usecols=['SupplierID','CompanyName', 'City'])

products = pd.read_csv(r'C:\Users\maxym\Desktop\cheatsheets\pandas_anaconda_numpy\course-files\northwind-mongo-master\products_del_2.csv',
                      usecols=['ProductID','ProductName', 'SupplierID'])

# %%
f'suppliers:{len(suppliers)}, products:{len(products)}'
# Out:
# 'suppliers:29, products:68'

# %%
sup_prod_left = suppliers.merge(products, on='SupplierID',how='left', indicator=True)

# %%
sup_prod_left['_merge'].value_counts()
# Out:
# both          68
# left_only      2
# right_only     0
# Name: _merge, dtype: int64

# %%
sup_prod_right = products.merge(suppliers, on='SupplierID',how='right', indicator=True)

# %%
filtering_left = sup_prod_left['_merge'] == 'left_only'
filtering_right = sup_prod_right['_merge'] == 'right_only'

# %%
sup_prod_left.head()
# Out:
#    SupplierID                 CompanyName         City  ProductID  \
# 0           1              Exotic Liquids       London        1.0
# 1           1              Exotic Liquids       London        2.0
# 2           2  New Orleans Cajun Delights  New Orleans        NaN
# 3           3   Grandma Kelly's Homestead    Ann Arbor        6.0
# 4           3   Grandma Kelly's Homestead    Ann Arbor        7.0
#
#                        ProductName     _merge
# 0                             Chai       both
# 1                            Chang       both
# 2                              NaN  left_only
# 3     Grandma's Boysenberry Spread       both
# 4  Uncle Bob's Organic Dried Pears       both

# %%
sup_prod_right['_merge'].value_counts()
# Out:
# both          68
# right_only     2
# left_only      0
# Name: _merge, dtype: int64

# %%
sup_prod_right[filtering_right]
# Out:
#     ProductID ProductName  SupplierID                 CompanyName  \
# 2         NaN         NaN           2  New Orleans Cajun Delights
# 67        NaN         NaN          27          Escargots Nouveaux
#
#            City      _merge
# 2   New Orleans  right_only
# 67     Montceau  right_only

# %%
sup_prod_left[filtering_left]
# Out:
#     SupplierID                 CompanyName         City  ProductID  \
# 2            2  New Orleans Cajun Delights  New Orleans        NaN
# 67          27          Escargots Nouveaux     Montceau        NaN
#
#    ProductName     _merge
# 2          NaN  left_only
# 67         NaN  left_only

# %% [markdown]
# # additional parameters of merge

# %%
suppliers = pd.read_csv(r'C:\Users\maxym\Desktop\cheatsheets\pandas_anaconda_numpy\course-files\northwind-mongo-master\suppliers.csv',
                       usecols=['SupplierID','CompanyName','City'])
suppliers.head()
# Out:
#    SupplierID                         CompanyName         City
# 0           1                      Exotic Liquids       London
# 1           2          New Orleans Cajun Delights  New Orleans
# 2           3           Grandma Kelly's Homestead    Ann Arbor
# 3           4                       Tokyo Traders        Tokyo
# 4           5  Cooperativa de Quesos 'Las Cabras'       Oviedo

# %%
products = pd.read_csv(r'C:\Users\maxym\Desktop\cheatsheets\pandas_anaconda_numpy\course-files\northwind-mongo-master\products.csv',
                       usecols=['ProductID','ProductName','SupplierID'])
products.head()
# Out:
#    ProductID                   ProductName  SupplierID
# 0          1                          Chai           1
# 1          2                         Chang           1
# 2          3                 Aniseed Syrup           1
# 3          4  Chef Anton's Cajun Seasoning           2
# 4          5        Chef Anton's Gumbo Mix           2

# %%
suppliers.merge(products, on='SupplierID')
# Out:
#     SupplierID                 CompanyName           City  ProductID  \
# 0            1              Exotic Liquids         London          1
# 1            1              Exotic Liquids         London          2
# 2            1              Exotic Liquids         London          3
# 3            2  New Orleans Cajun Delights    New Orleans          4
# 4            2  New Orleans Cajun Delights    New Orleans          5
# ..         ...                         ...            ...        ...
# 72          27          Escargots Nouveaux       Montceau         58
# 73          28                Gai pâturage         Annecy         59
# 74          28                Gai pâturage         Annecy         60
# 75          29            Forêts d'érables  Ste-Hyacinthe         61
# 76          29            Forêts d'érables  Ste-Hyacinthe         62
#
#                      ProductName
# 0                           Chai
# 1                          Chang
# 2                  Aniseed Syrup
# ...

# %%
suppliers.set_index("SupplierID", inplace=True)

# %%
suppliers.merge(products, left_index=True, right_on="SupplierID").head(3)
# Out:
#       CompanyName    City  ProductID    ProductName  SupplierID
# 0  Exotic Liquids  London          1           Chai           1
# 1  Exotic Liquids  London          2          Chang           1
# 2  Exotic Liquids  London          3  Aniseed Syrup           1

# %%
products.set_index("SupplierID",inplace=True)

# %%
suppliers.join(products).head(3)
# Out:
#                CompanyName    City  ProductID    ProductName
# SupplierID
# 1           Exotic Liquids  London          1           Chai
# 1           Exotic Liquids  London          2          Chang
# 1           Exotic Liquids  London          3  Aniseed Syrup

# %%
suppliers.reset_index(inplace=True)

# %%
suppliers.merge(products, left_on="SupplierID", right_index=True).head(3)
# Out:
#    SupplierID     CompanyName    City  ProductID    ProductName
# 0           1  Exotic Liquids  London          1           Chai
# 0           1  Exotic Liquids  London          2          Chang
# 0           1  Exotic Liquids  London          3  Aniseed Syrup

# %%
products.reset_index(inplace=True)

# %%
products.rename({'SupplierID':'supplier_id'}, axis=1, inplace=True)

# %%
suppliers.merge(products, left_on="SupplierID", right_on="supplier_id").head(3)
# Out:
#    SupplierID     CompanyName    City  supplier_id  ProductID    ProductName
# 0           1  Exotic Liquids  London            1          1           Chai
# 1           1  Exotic Liquids  London            1          2          Chang
# 2           1  Exotic Liquids  London            1          3  Aniseed Syrup

# %%
products = pd.read_csv(r'C:\Users\maxym\Desktop\cheatsheets\pandas_anaconda_numpy\course-files\northwind-mongo-master\products.csv',
                       usecols=['ProductID','ProductName','SupplierID','CategoryID'])

suppliers = pd.read_csv(r'C:\Users\maxym\Desktop\cheatsheets\pandas_anaconda_numpy\course-files\northwind-mongo-master\suppliers.csv',
                       usecols=['SupplierID','CompanyName','City'])

categories = pd.read_csv(r'C:\Users\maxym\Desktop\cheatsheets\pandas_anaconda_numpy\course-files\northwind-mongo-master\categories1.csv',
                        usecols=['CategoryID','CategoryName'], index_col='CategoryID')

# %%
prod_cat = products.merge(categories, left_on='CategoryID', right_index=True)

# %%
prod_cat
# Out:
#     ProductID                    ProductName  SupplierID  CategoryID  \
# 0           1                           Chai           1           1
# 1           2                          Chang           1           1
# 23         24             Guaraná Fantástica          10           1
# 33         34                  Sasquatch Ale          16           1
# 34         35                 Steeleye Stout          16           1
# ..        ...                            ...         ...         ...
# 41         42  Singaporean Hokkien Fried Mee          20           5
# 51         52                       Filo Mix          24           5
# 55         56         Gnocchi di nonna Alice          26           5
# 56         57                 Ravioli Angelo          26           5
# 63         64      Wimmers gute Semmelknödel          12           5
#
#       CategoryName
# 0        Beverages
# 1        Beverages
# 23       Beverages
# 33       Beverages
# 34       Beverages
# ...

# %%
prod_cat_sup = prod_cat.merge(suppliers, on='SupplierID')

# %%
products.merge(categories, left_on='CategoryID', right_index=True).merge(suppliers, on='SupplierID').head()
# Out:
#    ProductID         ProductName  SupplierID  CategoryID CategoryName  \
# 0          1                Chai           1           1    Beverages
# 1          2               Chang           1           1    Beverages
# 2          3       Aniseed Syrup           1           2   Condiments
# 3         24  Guaraná Fantástica          10           1    Beverages
# 4         34       Sasquatch Ale          16           1    Beverages
#
#                  CompanyName       City
# 0             Exotic Liquids     London
# 1             Exotic Liquids     London
# 2             Exotic Liquids     London
# 3  Refrescos Americanas LTDA  Sao Paulo
# 4          Bigfoot Breweries       Bend
